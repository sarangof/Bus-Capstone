# %%
import sys
sys.path.append('/gpfs2/projects/project-bus_capstone_2016/workspace/mu529/Bus-Capstone')

import numpy as np

import seqtools

# %%
a = [.34, .39, .68, .68, .88]
b = [.33, .41, .44, .90]

# %%
seqtools.align_pwise(a,b)
# Out:
# [(0.34, 0.33), (0.39, 0.41), ('', 0.44), (0.68, ''), (0.68, '')]

# %%
c = np.random.randn(10000)
d = np.random.randn(10000) 
c.sort()
d.sort()

# %%
e = seqtools.align_pwise(c,d)
e
# Out:
# [(-4.5754840159566257, ''),
#  ('', -4.4896852559917271),
#  ('', -4.1418190935039743),
#  (-3.8047047373720768, ''),
#  ('', -3.7281645393044904),
#  (-3.7202375439461197, ''),
#  (-3.5877505954657596, ''),
#  ('', -3.549803542839761),
#  ('', -3.5374791856566592),
#  (-3.5147221626923382, ''),
#  ('', -3.5127843362214306),
#  (-3.5012986566710409, ''),
#  (-3.4969455904026514, ''),
#  (-3.4624907388527997, ''),
#  (-3.4490962701451466, ''),
#  (-3.4214406927754313, ''),
#  (-3.3974652353574224, ''),
#  ('', -3.354486960327669),
#  (-3.3520324870520701, ''),
#  (-3.3045093673986239, ''),
#  ('', -3.278091225594582),
#  ('', -3.2379840368832329),
#  ('', -3.1841429007727586),
#  ('', -3.1684491618431645),
#  (-3.1593413883640706, ''),
#  ('', -3.1403735237442389),
#  (-3.1248193136956597, ''),
#  ('', -3.1010298662416838),
#  (-3.0986576477721819, ''),
#  (-3.0984275400065231, ''),
#  (-3.067171834782815, ''),
#  (-3.0453688184657159, ''),
#  (-3.0392734231818745, ''),
# ...
